# %% [markdown]
# # 00 — Colab Setup
#
# Skeleton only (Phase 2, not yet written). Will bootstrap the Colab Pro environment for this project's notebooks, mirroring the prior QAT project's `notebooks/00_colab_setup.ipynb`: mount Drive for results, clone this repo's GitHub remote (once provided) into `/content/<repo>`, install Colab-side deps (llmcompressor, bitsandbytes, vLLM, etc.).

# %%
# TODO (Phase 2): drive mount, repo clone/pull, pip installs.
# See quant research/notebooks/00_colab_setup.ipynb and 15_mixed_precision_guided_targeted_qat.ipynb
# (cell-1/cell-2) for the established pattern to adapt.
